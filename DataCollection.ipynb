# %%
from googleapiclient.discovery import build
key='AIzaSyCk74u-ST1LmFwAfd6LtXpGGeuq8jYMDkQ'
youtube=build('youtube','v3',developerKey=key)

playlist_ids=['PLqnslRFeH2Upcrywf-u2etjdxxkL8nl7E','PLcWfeUsAys2k_xub3mHks85sBHZvg24Jd','PLoROMvodv4rMiGQp3WXShtMGgzqpfVfbU','PLkguTFqZ9THFtRU9V-8ocNyG8iyw4RXBe','PLxfEOJXRm7eZTNMFXDxlPZZP9i8ebDIuL','PLEiEAq2VkUULYYgj13YHUWmRePqiu8Ddy','PLQVvvaa0QuDfKTOs3Keq_kaG2P55YRn5v','PLl4kuMJ32K2r2CUKkZSVVxDnjB4NM335-']
all_data=[]

for ids in playlist_ids:
    request=youtube.playlistItems().list(
            part='snippet',
            playlistId=ids,
            #fields=f"nextPageToken,{fields}",
            maxResults=50,
    )
    response = request.execute()

    for i in range(len(response['items'])):
        data=dict(channel_id = response['items'][i]['id'],
                  video_title = response['items'][i]["snippet"]["title"],
                  channel_name = response['items'][i]["snippet"]["channelTitle"])
        all_data.append(data)

# %%
import pandas as pd
df=pd.DataFrame(all_data)
df
# Out:
#                                             channel_id  \
# 0    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 1    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 2    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 3    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 4    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# ..                                                 ...
# 198  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 199  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 200  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 201  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 202  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
#
#                                            video_title  \
# 0    KNN (K Nearest Neighbors) in Python - Machine ...
# 1    Linear Regression in Python - Machine Learning...
# 2    Logistic Regression in Python - Machine Learni...
# 3    Linear and Logistic Regression in 60 lines of ...
# ...

# %%
video_ids = []
for ids in playlist_ids:
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = ids,
                maxResults = 50)
    response = request.execute()
       
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

# %%
len(video_ids)
# Out:
# 203

# %%
video_ids
# Out:
# ['ngLyX54e1LU',
#  '4swNt7PiamQ',
#  'JDU3AzH3WKg',
#  'PC7cVBbU7UQ',
#  'BqUmKsfSWho',
#  't2ym2a3pb_Y',
#  'UX0f9BNBcsY',
#  'jVh5NA9ERDA',
#  'Bqi7EFFvNOg',
#  'Oq1cKjR8hNo',
#  '52d7ha-GdV8',
#  'vtuH4VRq1AU',
#  'wF5t4Mmv5us',
#  '9IDXYHhAfGA',
#  'eivDTOlA0TE',
#  'p1hGz0w_OCo',
#  'rTEtEy5o3X0',
#  'ltXSoduiVwY',
#  'YYEJ_GUguHw',
#  'NxEHSAfFlK8',
#  'kFwe2ZZU7yw',
#  'TLInuAorxqE',
#  'Rjr62b_h7S4',
#  'aOEoxyA4uXU',
#  'T9UcK-TxQGw',
#  '6UF5Ysk_2gk',
#  'jGwO_UgTS7I',
#  '4b4MUYve_U8',
#  'het9HFqo1TQ',
#  'iZTeva0WSTQ',
#  'nt63k3bfXS0',
#  'lDwow4aOrtg',
#  '8NYoQiRANpg',
#  'rjbkWSTjHzM',
#  'iVOxMcumR4A',
#  'wr9gUr-eWdA',
#  'MfIjxPh6Pys',
#  'zUazLXZZA2U',
#  'ORrStCArmP4',
#  'rVfZHWTwXSA',
#  'tw6cmL5STuY',
#  'YQA9lLdLig8',
#  'd5gaWTo6kDM',
#  'QFu5nuc-S0s',
#  '0rt2CsEQv6U',
#  'pLhPQynL0tY',
#  '0p0o5cmgLdE',
#  'jr_BcU4QlNE',
#  'mEGYznC6F9s',
#  'ddfxpzHTb6E',
#  'ny1iZ5A8ilA',
#  'JcI5E2Ng6r4',
#  '2cK_l1hbQao',
#  'jat9foKPJfs',
#  'W81zG1Fv9Vk',
# ...

# %%
df['video_ids']=video_ids

# %%
df
# Out:
#                                             channel_id  \
# 0    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 1    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 2    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 3    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 4    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# ..                                                 ...
# 198  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 199  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 200  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 201  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
# 202  UExsNGt1TUozMksycjJDVUtrWlNWVnhEbmpCNE5NMzM1LS...
#
#                                            video_title  \
# 0    KNN (K Nearest Neighbors) in Python - Machine ...
# 1    Linear Regression in Python - Machine Learning...
# 2    Logistic Regression in Python - Machine Learni...
# 3    Linear and Logistic Regression in 60 lines of ...
# ...

# %%
all_video_stats = []
    
for i in range(0, len(video_ids), 50):
    request = youtube.videos().list(
                    part='snippet,contentDetails',
                    id=','.join(video_ids[i:i+50]))
    response = request.execute()
        
    for video in response['items']:
        if 'tags' in video['snippet']:
            tag = video['snippet']['tags']
        else:
            tag = []
        video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               description=video['snippet']['description'],
                               tags=tag
                               )
        all_video_stats.append(video_stats)

# %%
df2=pd.DataFrame(all_video_stats)
df2['video_ids']=video_ids
df2.describe()
# Out:
#                                                     Title  \
# count                                                 203
# unique                                                203
# top     KNN (K Nearest Neighbors) in Python - Machine ...
# freq                                                    1
#
#               Published_date  \
# count                    203
# unique                   203
# top     2019-09-03T15:00:07Z
# freq                       1
#
#                                               description tags    video_ids
# count                                                 203  203          203
# unique                                                187  118          203
# top     If you liked the content please subscribe and ...   []  ngLyX54e1LU
# freq                                                   16   66            1

# %%
machine_learning= pd.merge(df, df2, on="video_ids")

# %%
machine_learning['class']='machine learning'

# %%
machine_learning['class']
# Out:
# 0      machine learning
# 1      machine learning
# 2      machine learning
# 3      machine learning
# 4      machine learning
#              ...
# 198    machine learning
# 199    machine learning
# 200    machine learning
# 201    machine learning
# 202    machine learning
# Name: class, Length: 203, dtype: object

# %%
playlist_ids=['PLblh5JKOoLUK0FLuzwntyYI10UQFUhsY9','PLUl4u3cNGP60uVBMaoNERc6knT_MgPKS0','PLZoTAELRMXVMhVyr3Ri9IQ-t5QPBtxzJO','PLlz0muypSBNY42VjQyMl248ye6v--FIGw','PL0o_zxa4K1BVsziIRdfv4Hl4UIqDZhXWV','PL1328115D3D8A2566']
all_data=[]


for ids in playlist_ids:
    request=youtube.playlistItems().list(
            part='snippet',
            playlistId=ids,
            #fields=f"nextPageToken,{fields}",
            maxResults=50,
    )
    response = request.execute()

    for i in range(len(response['items'])):
        data=dict(channel_id = response['items'][i]['id'],
                  video_title = response['items'][i]["snippet"]["title"],
                  channel_name = response['items'][i]["snippet"]["channelTitle"])
        all_data.append(data)

# %%
st=pd.DataFrame(all_data)
st
# Out:
#                                             channel_id  \
# 0    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 1    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 2    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 3    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 4    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# ..                                                 ...
# 215    UEwxMzI4MTE1RDNEOEEyNTY2Ljg4Q0E1NTJERDQzMTg0QTI
# 216    UEwxMzI4MTE1RDNEOEEyNTY2LjA0QjVEOTZGRTE4MDlDNUE
# 217    UEwxMzI4MTE1RDNEOEEyNTY2LkEzRjcwNjQ1MjA1RTNGRjk
# 218    UEwxMzI4MTE1RDNEOEEyNTY2LjMyQTQzNjkyMUI5RDJFODM
# 219    UEwxMzI4MTE1RDNEOEEyNTY2LjlGN0IwQzY5QzQ5NkZERkM
#
#                                            video_title  \
# 0             StatQuest: Histograms, Clearly Explained
# 1      The Main Ideas behind Probability Distributions
# 2        The Normal Distribution, Clearly Explained!!!
# 3                  The mean, the median, and the mode.
# ...

# %%
video_ids = []
for ids in playlist_ids:
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = ids,
                maxResults = 50)
    response = request.execute()
       
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
video_ids
# Out:
# ['qBigTkBLU6g',
#  'oI3hZJqXJuc',
#  'rzFX5NWojp0',
#  '-14BImgVENA',
#  'wtLQUjfomig',
#  'vikkiwjQqfU',
#  'SzZ6GpcfoQY',
#  'yQhTtdq_y9M',
#  'XLCWeSVzHUU',
#  '0oc49DyA3hU',
#  '5koKb5B_YWo',
#  'vemZtEM63GY',
#  'JQc3yx0-Q9E',
#  'HDCOUXE3HMM',
#  'K8LQSvtjcEo',
#  'Rsc5znwR5FA',
#  'VX_M3tIyiYk',
#  'qtaqvPAeEJY',
#  'xZ_z8KWkhXE',
#  '_IgyaD7vOOA',
#  '9wCnvr7Xw4E',
#  'KLs_7b7SKi4',
#  'OSPr6G6Ka-U',
#  'J8jNoF-K8E8',
#  'YAlJCEDH2uY',
#  'Exk0OoRG0PQ',
#  '67zCIqdeXpo',
#  'A82brFpdr9g',
#  'XNgt7F6FqDU',
#  'Xz0x-8-cgaQ',
#  'N4ZQQqyIf6k',
#  'RiEZ_hEf96A',
#  'fHLhBnmwUM0',
#  'VSi0Z04fWj0',
#  'TqOeMYtOc1w',
#  '2AQKmw14mHM',
#  'PaFPbb66DxQ',
#  'Vf7oJ6z2LCc',
#  'nk2CQITm_eo',
#  'u1cc1r_Y7M0',
#  'zITIFTsivN8',
#  'hokALdIst8k',
#  'NF5_btOaCig',
#  '2UYx-qjJGSs',
#  'i4iUvjsGCMc',
#  'KEofcJ1tfkI',
#  'nnBJeb_I-q8',
#  'bsZGt-caXO4',
#  'IFKQLDmRK0Y',
#  'okjYjClSjOg',
#  'VPZD_aij8H0',
#  'C_W1adH-NVE',
#  'TSkDZbGS94k',
#  'rLlZpnT02ZU',
#  '0Va2dOLqUfM',
# ...

# %%
len(video_ids)
# Out:
# 220

# %%
st['video_ids']=video_ids
st
# Out:
#                                             channel_id  \
# 0    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 1    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 2    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 3    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 4    UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# ..                                                 ...
# 215    UEwxMzI4MTE1RDNEOEEyNTY2Ljg4Q0E1NTJERDQzMTg0QTI
# 216    UEwxMzI4MTE1RDNEOEEyNTY2LjA0QjVEOTZGRTE4MDlDNUE
# 217    UEwxMzI4MTE1RDNEOEEyNTY2LkEzRjcwNjQ1MjA1RTNGRjk
# 218    UEwxMzI4MTE1RDNEOEEyNTY2LjMyQTQzNjkyMUI5RDJFODM
# 219    UEwxMzI4MTE1RDNEOEEyNTY2LjlGN0IwQzY5QzQ5NkZERkM
#
#                                            video_title  \
# 0             StatQuest: Histograms, Clearly Explained
# 1      The Main Ideas behind Probability Distributions
# 2        The Normal Distribution, Clearly Explained!!!
# 3                  The mean, the median, and the mode.
# ...

# %%
all_video_stats = []
    
for i in range(0, len(video_ids), 50):
    request = youtube.videos().list(
                    part='snippet,contentDetails',
                    id=','.join(video_ids[i:i+50]))
    response = request.execute()
        
    for video in response['items']:
        if 'tags' in video['snippet']:
            tag = video['snippet']['tags']
        else:
            tag = []
        video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               description=video['snippet']['description'],
                               tags=tag
                               )
        all_video_stats.append(video_stats)

# %%
st2=pd.DataFrame(all_video_stats)
st2['video_ids']=video_ids
st2.describe()
# Out:
#                                            Title        Published_date  \
# count                                        220                   220
# unique                                       220                   213
# top     StatQuest: Histograms, Clearly Explained  2017-08-17T20:51:46Z
# freq                                           1                     2
#
#                                               description tags    video_ids
# count                                                 220  220          220
# unique                                                208  152          220
# top     ⭐ Kite is a free AI-powered coding assistant t...   []  qBigTkBLU6g
# freq                                                    6   58            1

# %%
statistics= pd.merge(st, st2, on="video_ids")
statistics['class']='statistics'

# %%
statistics.head(10)
# Out:
#                                           channel_id  \
# 0  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 1  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 2  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 3  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 4  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 5  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 6  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 7  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 8  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
# 9  UExibGg1SktPb0xVSzBGTHV6d250eVlJMTBVUUZVaHNZOS...
#
#                                          video_title  \
# 0           StatQuest: Histograms, Clearly Explained
# 1    The Main Ideas behind Probability Distributions
# 2      The Normal Distribution, Clearly Explained!!!
# 3                The mean, the median, and the mode.
# 4                       The Exponential Distribution
# 5  Population and Estimated Parameters, Clearly E...
# ...

# %%
playlist_ids=['PLWKjhJtqVAbnqBxcdjVGgT3uVR10bzTEB','PLqnslRFeH2UqLwzS0AwKDKLrpYBKzLBy2','PLzMcBGfZo4-mFu00qxl0a67RhjjZj3jXm','PLqXS1b2lRpYTQQ8ziHakWZHLFIheVhcOg','PLTjRvDozrdlxj5wgH4qkvwSOdHLOCx10f','PLavw5C92dz9FePZXIo4jpsupqp3X0w2SW','PL-osiE80TeTskrapNbzXhwoFUiLCjGgY7','PLvMRWNpDTNwTNwsQmgTvvG2i1znjfMidt','PLwvrYc43l1MzSBvslCMVZGtLLaZTq3VTG']
all_data=[]


for ids in playlist_ids:
    request=youtube.playlistItems().list(
            part='snippet',
            playlistId=ids,
            #fields=f"nextPageToken,{fields}",
            maxResults=50,
    )
    response = request.execute()

    for i in range(len(response['items'])):
        data=dict(channel_id = response['items'][i]['id'],
                  video_title = response['items'][i]["snippet"]["title"],
                  channel_name = response['items'][i]["snippet"]["channelTitle"])
        all_data.append(data)

# %%
py=pd.DataFrame(all_data)
py
# Out:
#                                             channel_id  \
# 0    UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# 1    UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# 2    UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# 3    UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# 4    UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# ..                                                 ...
# 192  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 193  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 194  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 195  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 196  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
#
#                                            video_title      channel_name
# 0    Learn Python - Full Course for Beginners [Tuto...  freeCodeCamp.org
# 1    Tkinter Course - Create Graphic User Interface...  freeCodeCamp.org
# 2    Learn Python by Building Five Games - Full Course  freeCodeCamp.org
# ...

# %%
video_ids = []
for ids in playlist_ids:
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = ids,
                maxResults = 50)
    response = request.execute()
       
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
video_ids
# Out:
# ['rfscVS0vtbw',
#  'YXPyB4XeYLA',
#  'XGf2GcyHPhc',
#  '8DvywoWv6fI',
#  'F5mRW0jo-U4',
#  'zfvxp7PgQ6c',
#  'p65AHm9MX80',
#  'McoDjOCb2Zo',
#  'E-1xI85Zog8',
#  'CD4qAhfFuLo',
#  '87Gx3U0BDlo',
#  'XpYz-q1lxu8',
#  '8u-zJVVVhT4',
#  'qCQGV7F7CUc',
#  'X2vAabgKiuM',
#  'C6jJg9Zan7w',
#  'TbMKwl11itQ',
#  '8392NJjj8s0',
#  'FfWpgLFMI7w',
#  'byHcYRpMgI4',
#  'LHBE6Q9XlzI',
#  'FGdiSJakIS4',
#  '_ZqAVck-WeM',
#  'HGOBQPFzWKo',
#  'EsDFiZPljYo',
#  'WcDaZ67TVRo',
#  'QLTdOEn79Rc',
#  'Kes8YRV73Io',
#  'LTXnQdrwyrw',
#  'Qs3BSFZnZSI',
#  'e6ivlABOYRI',
#  'UdcPhnNjSEw',
#  '3ecISAkioPc',
#  'D2TJ9wvSP94',
#  'qOuOV4pDVGY',
#  'p0A4CV4MWd0',
#  'EtAGd-3arNE',
#  'CsLsGCbnlJY',
#  'FXUUSfJO_J4',
#  '4CxB2V2lERs',
#  'vbtxtvuCFRM',
#  'usyg5vbni34',
#  'IT8RYokUvvQ',
#  'iSEyb7ehLK0',
#  'M7daahMOMMc',
#  'RQ6Ur_T0G3Y',
#  'YE6a31J65Rc',
#  'OFrLs22MDAw',
#  'QQrcd_62VWM',
#  '2EngAQX_kCg',
#  'vA4r_MPRNsg',
#  'IRiJdLN-Ers',
#  'vKeoXxVaga4',
#  'U_nugSKtbSk',
#  '1uCH3zqbv2s',
# ...

# %%
len(video_ids)
# Out:
# 197

# %%
py['video_ids']=video_ids
py.describe()
# Out:
#                                                channel_id  \
# count                                                 197
# unique                                                197
# top     UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# freq                                                    1
#
#                                               video_title      channel_name  \
# count                                                 197               197
# unique                                                197                 9
# top     Learn Python - Full Course for Beginners [Tuto...  freeCodeCamp.org
# freq                                                    1                26
#
#           video_ids
# count           197
# unique          197
# top     rfscVS0vtbw
# freq              1

# %%
all_video_stats = []
    
for i in range(0, len(video_ids), 50):
    request = youtube.videos().list(
                    part='snippet,contentDetails',
                    id=','.join(video_ids[i:i+50]))
    response = request.execute()
        
    for video in response['items']:
        if 'tags' in video['snippet']:
            tag = video['snippet']['tags']
        else:
            tag = []
        video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               description=video['snippet']['description'],
                               tags=tag
                               )
        all_video_stats.append(video_stats)

# %%
py2=pd.DataFrame(all_video_stats)
py2['video_ids']=video_ids
py2.describe()
# Out:
#                                                     Title  \
# count                                                 197
# unique                                                197
# top     Learn Python - Full Course for Beginners [Tuto...
# freq                                                    1
#
#               Published_date  \
# count                    197
# unique                   196
# top     2018-07-26T17:30:01Z
# freq                       2
#
#                                               description  \
# count                                                 197
# unique                                                195
# top     Hi Welcome to Amigoscode. Intuit QuickBooks an...
# freq                                                    3
#
#                                                      tags    video_ids
# count                                                 197          197
# unique                                                154          197
# ...

# %%
python= pd.merge(py, py2, on="video_ids")
python['class']='python'

# %%
python.describe()
# Out:
#                                                channel_id  \
# count                                                 197
# unique                                                197
# top     UExXS2poSnRxVkFibnFCeGNkalZHZ1QzdVZSMTBielRFQi...
# freq                                                    1
#
#                                               video_title      channel_name  \
# count                                                 197               197
# unique                                                197                 9
# top     Learn Python - Full Course for Beginners [Tuto...  freeCodeCamp.org
# freq                                                    1                26
#
#           video_ids                                              Title  \
# count           197                                                197
# unique          197                                                197
# top     rfscVS0vtbw  Learn Python - Full Course for Beginners [Tuto...
# ...

# %%
result_df = pd.concat([machine_learning,statistics])

# %%
result_df
# Out:
#                                             channel_id  \
# 0    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 1    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 2    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 3    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 4    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# ..                                                 ...
# 215    UEwxMzI4MTE1RDNEOEEyNTY2Ljg4Q0E1NTJERDQzMTg0QTI
# 216    UEwxMzI4MTE1RDNEOEEyNTY2LjA0QjVEOTZGRTE4MDlDNUE
# 217    UEwxMzI4MTE1RDNEOEEyNTY2LkEzRjcwNjQ1MjA1RTNGRjk
# 218    UEwxMzI4MTE1RDNEOEEyNTY2LjMyQTQzNjkyMUI5RDJFODM
# 219    UEwxMzI4MTE1RDNEOEEyNTY2LjlGN0IwQzY5QzQ5NkZERkM
#
#                                            video_title    channel_name  \
# 0    KNN (K Nearest Neighbors) in Python - Machine ...  Patrick Loeber
# 1    Linear Regression in Python - Machine Learning...  Patrick Loeber
# 2    Logistic Regression in Python - Machine Learni...  Patrick Loeber
# ...

# %%
result_df=pd.concat([result_df,python])

# %%
result_df
# Out:
#                                             channel_id  \
# 0    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 1    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 2    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 3    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 4    UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# ..                                                 ...
# 192  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 193  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 194  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 195  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
# 196  UEx3dnJZYzQzbDFNelNCdnNsQ01WWkd0TExhWlRxM1ZURy...
#
#                                            video_title    channel_name  \
# 0    KNN (K Nearest Neighbors) in Python - Machine ...  Patrick Loeber
# 1    Linear Regression in Python - Machine Learning...  Patrick Loeber
# 2    Logistic Regression in Python - Machine Learni...  Patrick Loeber
# ...

# %%
playlist_ids=['PLAMhkzmvYCLMZmpM-BKuwVwJ-Kj_xMsRx','PLTnRtjQN5iebOa_b4K3MmAoRkPj_XNTgp','PLEiEAq2VkUUIJ3o1tehvtux0_Ynf42CBN','PLy3rlBrKb7nyNp57ffFWJsL7IbPFTW1oo','PLy3rlBrKb7nyWT1uKJspzqefnuv5rC_mM','PLy3rlBrKb7nyeLdX_N6yYWUFr6eBObFnh','PLJcaPjxegjBWWtJHeKzGTTa5JF4UrO2o_','PLIivdWyY5sqI0qjprNZV0d8D8MRcYk6xp','PLrjkTql3jnm86_Jr9195OaqN-HeiBy49I']
all_data=[]


for ids in playlist_ids:
    request=youtube.playlistItems().list(
            part='snippet',
            playlistId=ids,
            #fields=f"nextPageToken,{fields}",
            maxResults=50,
    )
    response = request.execute()

    for i in range(len(response['items'])):
        data=dict(channel_id = response['items'][i]['id'],
                  video_title = response['items'][i]["snippet"]["title"],
                  channel_name = response['items'][i]["snippet"]["channelTitle"])
        all_data.append(data)

# %%
cl=pd.DataFrame(all_data)
cl
# Out:
#                                             channel_id  \
# 0    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 1    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 2    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 3    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 4    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# ..                                                 ...
# 197  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 198  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 199  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 200  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 201  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
#
#                                            video_title     channel_name
# 0    How to create a Wordpress website - Microsft A...  Cloud Computing
# 1     How to use Azure Cloud Shell to create a Web App  Cloud Computing
# 2                 How to create Azure Virtual Machines  Cloud Computing
# ...

# %%
video_ids = []
for ids in playlist_ids:
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = ids,
                maxResults = 50)
    response = request.execute()
       
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

# %%
len(video_ids)
# Out:
# 202

# %%
cl['video_ids']=video_ids
cl
# Out:
#                                             channel_id  \
# 0    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 1    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 2    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 3    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# 4    UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# ..                                                 ...
# 197  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 198  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 199  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 200  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
# 201  UExyamtUcWwzam5tODZfSnI5MTk1T2FxTi1IZWlCeTQ5SS...
#
#                                            video_title     channel_name  \
# 0    How to create a Wordpress website - Microsft A...  Cloud Computing
# 1     How to use Azure Cloud Shell to create a Web App  Cloud Computing
# 2                 How to create Azure Virtual Machines  Cloud Computing
# ...

# %%
all_video_stats = []
    
for i in range(0, len(video_ids), 50):
    request = youtube.videos().list(
                    part='snippet,contentDetails',
                    id=','.join(video_ids[i:i+50]))
    response = request.execute()
        
    for video in response['items']:
        if 'tags' in video['snippet']:
            tag = video['snippet']['tags']
        else:
            tag = []
        video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               description=video['snippet']['description'],
                               tags=tag
                               )
        all_video_stats.append(video_stats)

# %%
cl2=pd.DataFrame(all_video_stats)
cl2['video_ids']=video_ids
cl2.describe()
# Out:
#                                                     Title  \
# count                                                 202
# unique                                                198
# top     Cloud Architect Program - Learn AWS, Azure, Go...
# freq                                                    3
#
#               Published_date description  \
# count                    202         202
# unique                   186         176
# top     2018-08-14T16:39:10Z
# freq                       4          26
#
#                                                      tags    video_ids
# count                                                 202          202
# unique                                                139          202
# top     [cloud, cloud computing, google cloud, cloud c...  5ZjfpxomJks
# freq                                                   39            1

# %%
cloud_comp= pd.merge(cl, cl2, on="video_ids")
cloud_comp['class']='cloud computing'

# %%
cloud_comp.describe()
# Out:
#                                                channel_id  \
# count                                                 202
# unique                                                202
# top     UExBTWhrem12WUNMTVptcE0tQkt1d1Z3Si1Lal94TXNSeC...
# freq                                                    1
#
#                                               video_title channel_name  \
# count                                                 202          202
# unique                                                198            7
# top     Cloud Architect Program - Learn AWS, Azure, Go...  Simplilearn
# freq                                                    3           50
#
#           video_ids                                              Title  \
# count           202                                                202
# unique          202                                                198
# top     5ZjfpxomJks  Cloud Architect Program - Learn AWS, Azure, Go...
# ...

# %%
playlist_ids=['PL9yYRbwpkykvOXrZumtZWbuaXWHvjD8gi','PL6Omre3duO-OGTAMuFuDOS8wMuuxmyaiX' ,'PLEiEAq2VkUUJEvrsey26P-Bj4Vk6BLBVC','PL1N57mwBHtN0ufit2dISWvcOAIetKcstk','PLO9LeSU_vHCU_DHaLzEvsLxFdmB3Qcao_', 'PLVHgQku8Z934KPX-NXwWQzxf8eCr5vscI','PL1N57mwBHtN1AGWHnJMhtvJCIG_IlC07D','PLmd91OWgLVSKQlDJaOF1XmKghKturU5qK']
all_data=[]


for ids in playlist_ids:
    request=youtube.playlistItems().list(
            part='snippet',
            playlistId=ids,
            #fields=f"nextPageToken,{fields}",
            maxResults=50,
    )
    response = request.execute()

    for i in range(len(response['items'])):
        data=dict(channel_id = response['items'][i]['id'],
                  video_title = response['items'][i]["snippet"]["title"],
                  channel_name = response['items'][i]["snippet"]["channelTitle"])
        all_data.append(data)

# %%
vi=pd.DataFrame(all_data)
vi
# Out:
#                                             channel_id  \
# 0    UEw5eVlSYndwa3lrdk9Yclp1bXRaV2J1YVhXSHZqRDhnaS...
# 1    UEw5eVlSYndwa3lrdk9Yclp1bXRaV2J1YVhXSHZqRDhnaS...
# 2    UEw5eVlSYndwa3lrdk9Yclp1bXRaV2J1YVhXSHZqRDhnaS...
# 3    UEw5eVlSYndwa3lrdk9Yclp1bXRaV2J1YVhXSHZqRDhnaS...
# 4    UEw5eVlSYndwa3lrdk9Yclp1bXRaV2J1YVhXSHZqRDhnaS...
# ..                                                 ...
# 224  UExtZDkxT1dnTFZTS1FsREphT0YxWG1LZ2hLdHVyVTVxSy...
# 225  UExtZDkxT1dnTFZTS1FsREphT0YxWG1LZ2hLdHVyVTVxSy...
# 226  UExtZDkxT1dnTFZTS1FsREphT0YxWG1LZ2hLdHVyVTVxSy...
# 227  UExtZDkxT1dnTFZTS1FsREphT0YxWG1LZ2hLdHVyVTVxSy...
# 228  UExtZDkxT1dnTFZTS1FsREphT0YxWG1LZ2hLdHVyVTVxSy...
#
#                                            video_title         channel_name
# 0              Data Visualization 2018 Course Overview      Curran Kelleher
# 1                          Intro to Javascript in 2018      Curran Kelleher
# ...

# %%
video_ids = []
for ids in playlist_ids:
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = ids,
                maxResults = 50)
    response = request.execute()
       
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

# %%
len(video_ids)
# Out:
# 229

# %%
vi['video_ids']=video_ids

# %%
all_video_stats = []
    
for i in range(0, len(video_ids), 50):
    request = youtube.videos().list(
                    part='snippet,contentDetails',
                    id=','.join(video_ids[i:i+50]))
    response = request.execute()
        
    for video in response['items']:
        if 'tags' in video['snippet']:
            tag = video['snippet']['tags']
        else:
            tag = []
        video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               description=video['snippet']['description'],
                               tags=tag
                               )
        all_video_stats.append(video_stats)

# %%
vi2=pd.DataFrame(all_video_stats)
vi2['video_ids']=video_ids
vi2.describe()
# Out:
#                                                     Title  \
# count                                                 229
# unique                                                228
# top     Tableau Training for Beginners | Tableau Tutor...
# freq                                                    2
#
#               Published_date  \
# count                    229
# unique                   229
# top     2018-08-23T17:44:57Z
# freq                       1
#
#                                               description  \
# count                                                 229
# unique                                                229
# top     Overview of the course found here: https://cur...
# freq                                                    1
#
#                                                      tags    video_ids
# count                                                 229          229
# unique                                                178          229
# ...

# %%
visual_analysis= pd.merge(vi, vi2, on="video_ids")
visual_analysis['class']='visualisation'

# %%
visual_analysis.describe()
# Out:
#                                                channel_id  \
# count                                                 229
# unique                                                229
# top     UEw5eVlSYndwa3lrdk9Yclp1bXRaV2J1YVhXSHZqRDhnaS...
# freq                                                    1
#
#                                               video_title   channel_name  \
# count                                                 229            229
# unique                                                228              7
# top     Tableau Training for Beginners | Tableau Tutor...  Pavan Lalwani
# freq                                                    2             50
#
#           video_ids                                              Title  \
# count           229                                                229
# unique          229                                                228
# top     4e3NF8ez95w  Tableau Training for Beginners | Tableau Tutor...
# ...

# %%
result_df = pd.concat([result_df,cloud_comp,visual_analysis])

# %%
result_df.describe()
# Out:
#                                                channel_id  \
# count                                                1051
# unique                                               1051
# top     UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# freq                                                    1
#
#                                               video_title channel_name  \
# count                                                1051         1051
# unique                                               1046           34
# top     Cloud Architect Program - Learn AWS, Azure, Go...  Simplilearn
# freq                                                    3          137
#
#           video_ids                                              Title  \
# count          1051                                               1051
# unique         1051                                               1046
# top     ngLyX54e1LU  Cloud Architect Program - Learn AWS, Azure, Go...
# ...

# %%
result_df.to_csv('YouTube.csv')

# %%
result_df.head()
# Out:
#                                           channel_id  \
# 0  UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 1  UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 2  UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 3  UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
# 4  UExxbnNsUkZlSDJVcGNyeXdmLXUyZXRqZHh4a0w4bmw3RS...
#
#                                          video_title    channel_name  \
# 0  KNN (K Nearest Neighbors) in Python - Machine ...  Patrick Loeber
# 1  Linear Regression in Python - Machine Learning...  Patrick Loeber
# 2  Logistic Regression in Python - Machine Learni...  Patrick Loeber
# 3  Linear and Logistic Regression in 60 lines of ...  Patrick Loeber
# 4  Naive Bayes in Python - Machine Learning From ...  Patrick Loeber
#
#      video_ids                                              Title  \
# 0  ngLyX54e1LU  KNN (K Nearest Neighbors) in Python - Machine ...
# 1  4swNt7PiamQ  Linear Regression in Python - Machine Learning...
# ...
